# %% [markdown]
# Rather than the DDPG algorithm, try the REINFORCE algorithm

# %% [markdown]
# HELPFUL LINKS
# My REINFORCE hw: https://github.com/jendawkins/ecehw3/blob/master/Assignment%203%20-%20Policy%20Gradient%20(DDPG%20and%20REINFORCE)%20(2).ipynb
#
# Julia Cartpole REINFORCE: https://github.com/CarloLucibello/DeepRLexamples.jl/blob/master/examples/actor_critic_pong.jl

# %% [markdown]
# Brian: do you want to help with debugging this and I'll move on to the next step?

# %%
using Pkg

# %%
Pkg.add("Gym")
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %.0 %]  67.0 % Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]

# %%
Pkg.add("Knet")
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]

# %%
Pkg.add("Distributions")
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]

# %%
Pkg.add("Flux")
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]

# %%
using Flux
using Gym
using Distributions
# Out:
# ┌ Info: Recompiling stale cache file /Users/jenniferdawkins/.julia/compiled/v1.0/Flux/QdkVy.ji for Flux [587475ba-b771-5e3f-ad9e-33799f191a9c]
# └ @ Base loading.jl:1184

# %%
using Knet

# %%
using Statistics

# %%
env = GymEnv("BipedalWalker-v2");

# %%
s_n = env.observation_space.shape[1]; # continuous state space
a_n = env.action_space.shape[1]; # continuous action space
ha_n = [25,25];

# %% [markdown]
# Model mlp takes in state and outputs normal distribution over states and actions

# %%
x = [-1,-2,-3]
maximum(push!(x,0))
pop!(x)
x
# Out:
# 3-element Array{Int64,1}:
#  -1
#  -2
#  -3

# %%
struct History
    states
    actions
    rewards
    log_odds
end

# %%
h = History(zeros(Float32,0),zeros(Float32,0),zeros(Float32,0),zeros(Float32,0))
# Out:
# History(Float32[], Float32[], Float32[], Float32[])

# %%
h.actions
# Out:
# 0-element Array{Float32,1}

# %%
function relu(x::Any)
    return maximum(push!([x],0.0))
#     pop!(x)
end
# Out:
# relu (generic function with 1 method)

# %%
function softplus(x)
    return log(1+exp(x))
end
# Out:
# softplus (generic function with 1 method)

# %%
relu(3.0)
# Out:
# 3.0

# %%
function initweights(hidden, xsize=4, ysize=2)
    w = []
    x = xsize
    for y in [hidden...]
        push!(w, xavier(y, x))
        push!(w, zeros(y, 1))
        x = y
    end
    push!(w, xavier(ysize, x)) # Prob actions
    push!(w, zeros(ysize, 1))
    
    return w
end
# Out:
# initweights (generic function with 3 methods)

# %%
function predict(w, x)
    for i = 1:2:length(w)-2
        x = relu.(w[i] * x .+ w[i+1])
    end
    probs = w[end-1] * x .+ w[end]
    return probs
end
# Out:
# predict (generic function with 1 method)

# %%
mlp = Chain(
    Dense(s_n, ha_n[1], relu),
    Dense(ha_n[1], ha_n[2], relu),
    BatchNorm(ha_n[2]),
    Dense(ha_n[2], 2))
# Out:
# Chain(Dense(24, 25, relu), Dense(25, 25, relu), BatchNorm(25), Dense(25, 2))

# %%
function sample_action(logit,a_n)
    dist = Normal(logit[1],softplus(logit[2]));
    action = rand(dist,a_n);
    log_odds = log.(pdf(dist,action));
    return action, log_odds
end
# Out:
# sample_action (generic function with 1 method)

# %%
function update_policy(history, gamma=1.0)
    num_paths = length(history.rewards);
    rew_cums = [];
    lo = [0];
    policy_loss = [];
    for p_idx in num_paths
        R = 0;
        for r in reverse(history.reward[p_idx])
            R = r + gamma*R;
            pushfirst!(rew_cums, R)
        end
        append!(lo,history.log_odds[p_idx])
    end
    rew_cums = (rew_cums .- mean(rew_cums)) ./ (std(rew_cums) + 1e-5);
    policy_loss = -mean(lo.*rew_cums);
    return policy_loss
end
# Out:
# update_policy (generic function with 2 methods)

# %%
paths = Dict("reward"=>[[1,1,0,1],[2,1,0,1],[2,1,0,1]],"log_odds"=>[[-.1,-.4,.3,.2],[-.1,-.4,.3,.2],[-.1,-.4,.3,.2]]);
    num_paths = length(paths["reward"]);
    rew_cums = [];
    lo = [0.0];
    policy_loss = [];
    for p_idx in num_paths
        R = 0;
        for r in reverse(paths["reward"][p_idx])
            R = r + gamma*R;
            pushfirst!(rew_cums, R)
        end
        append!(lo,paths["log_odds"][p_idx])
    end
    rew_cums = (rew_cums .- mean(rew_cums)) ./ (std(rew_cums) + 1e-5);
    policy_loss = -mean(lo.*rew_cums);
# Out:
# DimensionMismatch("arrays could not be broadcast to a common size")
#
# Stacktrace:
#  [1] _bcs1 at ./broadcast.jl:439 [inlined]
#  [2] _bcs at ./broadcast.jl:433 [inlined]
#  [3] broadcast_shape at ./broadcast.jl:427 [inlined]
#  [4] combine_axes at ./broadcast.jl:422 [inlined]
#  [5] instantiate at ./broadcast.jl:266 [inlined]
#  [6] materialize(::Base.Broadcast.Broadcasted{Base.Broadcast.DefaultArrayStyle{1},Nothing,typeof(*),Tuple{Array{Float64,1},Array{Float64,1}}}) at ./broadcast.jl:724
#  [7] top-level scope at In[102]:15

# %% [markdown]
# Run Reinforce

# %%
n_iter = 1000;
avg_reward = 0;
avg_rewards = [];
step_list_rinforce = [];
total_steps = 0;
episodes = 0;
lr = 1e-3
min_timesteps_per_batch = 2000;
w = initweights(ha_n,s_n,2);
opt = [Adam(lr = lr) for _=1:length(w)];

for itr in 1:n_iter
    paths = [];
    steps = 0;
    batch_rew = 0;
    while steps < min_timesteps_per_batch
        ob = reset!(env)
        obs, acs, rews, log_odds = [],[],[],[];
        done = false;
        ep_rew = 0;
        while ~done
            policy_dist = predict(w,ob)
            action, log_odd = sample_action(policy_dist, a_n)
            next_state, reward, done, information = step!(env, action)
            append!(obs,ob)
            append!(acs,action)
            append!(rews,reward)
            append!(log_odds,log_odd)
            ob = next_state;
            steps +=1;
            ep_rew += reward
            if done
                episodes += 1;
                break
            end
        
        end
        batch_rew += ep_rew;
        append!(h.states, obs)
        append!(h.actions,acs)
        append!(h.rewards,rews)
        append!(h.log_odds,log_odds)
#         path = Dict("observation"=>obs,
#             "reward"=>rews,
#             "action"=>acs,
#             "log_odds"=>log_odds);
#         append!(paths, path)
    end
    println(batch_rew)
    avg_reward += 0.1* batch_rew + avg_reward*0.9;
#     cumulative_reward, policy_loss = update_policy(paths);
    println(avg_reward)
    dw = grad(update_policy)(h)
    update!(w,dw,opt)
end
# Out:
# -499.5711346318187
# -49.95711346318188
# P(History(Float32[0.00274737, -2.05491e-5, 0.00159851, -0.0159999, 0.0918685, -0.00210949, 0.860321, 0.00296151, 1.0, 0.0322741, -0.00210934, 0.853871, 0.00149185, 1.0, 0.440814, 0.44582, 0.461423, 0.48955, 0.534103, 0.602461, 0.709149, 0.885932, 1.0, 1.0, -0.0078546, -0.00549671, -0.0122355, 0.0017182, 0.450874, 0.999999, 0.0937306, -1.47687, 1.0, 0.347081, 0.00363744, 0.100798, 0.0607754, 1.0, 0.448272, 0.453363, 0.469229, 0.497833, 0.543139, 0.612654, 0.721147, 0.900921, 1.0, 1.0, -0.00673064, 0.00223927, -0.00648045, -0.0262002, 0.495597, 0.583352, -0.0230533, -1.0, 0.0, 0.370755, 0.301912, 0.00507033, -0.802493, 0.0, 0.447044, 0.452121, 0.467944, 0.496469, 0.541652, 0.610976, 0.719172, 0.898453, 1.0, 1.0, -0.0137438, -0.0141144, -0.0120648, -0.0316793, 0.475308, -0.227039, 0.100275, 1.0, 0.0, 0.445224, 0.9436, -0.123453, -1.09584, 0.0, 0.445514, 0.450573, 0.466342, 0.49477, 0.539797, 0.608884, 0.71671, 0.895377, 1.0, 1.0, -0.00462011, 0.0181648, 0.00634769, -0.036854, 0.475443, -0.00507, 0.0798047, -0.170063, 1.0, 0.44787, 0.0581076, -0.238776, -1.0, 0.0, 0.443811, 0.448851, 0.46456, 0.492879, 0.537734, 0.606557, 0.71397, 0.891955, 1.0, 1.0, -0.00802176, -0.00690963, -0.00629374, -0.0440104, 0.553938, 1.0, -0.0351379, -1.0, 1.0, 0.399779, -0.585895, -0.11594, 1.0, 0.0, 0.44171, 0.446726, 0.462361, 0.490545, 0.535188, 0.603686, 0.71059, 0.887733, 1.0, 1.0, 0.00073395, 0.0172433, 0.00474914, -0.0769654, 0.632764, 1.0, -0.147725, -1.0, 0.0, 0.346091, -0.608901, -0.225879, -0.999999, 0.0, 0.438091, 0.443066, 0.458572, 0.486526, 0.530803, 0.598739, 0.704768, 0.880459, 1.0, 1.0, 0.0147387, 0.027727, 0.012854, -0.0963168, 0.711574, 1.0, -0.260443, -1.0, 0.0, 0.25971, -1.0, -0.333325, -1.0, 0.0, 0.433581, 0.438505, 0.453852, 0.481517, 0.525339, 0.592576, 0.697513, 0.871395, 1.0, 1.0, 0.0366917, 0.0438445, 0.031138, -0.0932934, 0.728122, 0.229162, -0.37735, -1.0, 0.0, 0.140376, -1.48787, -0.212703, 0.976278, 0.0, 0.429255, 0.434129, 0.449323, 0.476713, 0.520097, 0.586663, 0.690553, 0.8627, 1.0, 1.0, 0.0482395, 0.0229453, 0.0190034, -0.11709, 0.791082, 0.788996, -0.503259, -1.08447, 0.0, 0.0358516, -1.28866, -0.0820937, 1.0, 0.0, 0.423754, 0.428566, 0.443565, 0.470604, 0.513433, 0.579145, 0.681704, 0.851645, 1.0, 1.0, 0.039824, -0.0169298, -0.016986, -0.14539, 0.870988, 1.0, -0.57254, -0.603803, 0.0, 0.0685256, 0.427718, -0.199066, -1.0, 0.0, 0.416892, 0.421627, 0.436383, 0.462984, 0.505118, 0.569767, 0.670665, 0.837855, 1.0, 1.0, 0.0344376, -0.010906, -0.0169156, -0.147741, 0.909687, 0.546729, -0.446256, 1.0, 0.0, 0.0832906, 0.216116, -0.31488, -1.0, 0.0, 0.409941, 0.414597, 0.429106, 0.455264, 0.496696, 0.560267, 0.659483, 0.823884, 1.0, 1.0, 0.0321585, -0.00467566, 0.00644576, -0.16696, 0.989343, 1.0, -0.562277, -1.0, 0.0, 0.0353238, -0.587971, -0.192994, 1.0, 0.0, 0.402088, 0.406654, 0.420886, 0.446542, 0.487181, 0.549534, 0.646849, 0.808101, 1.0, 1.0, 0.0360614, 0.00775597, 0.00731154, -0.166352, 1.00615, 0.243475, -0.480959, 0.648932, 0.0, -0.0265004, -0.760083, -0.0698315, 1.0, 0.0, 0.394287, 0.398765, 0.412721, 0.43788, 0.47773, 0.538873, 0.6343, 0.792424, 1.0, 1.0, 0.0488126, 0.0254611, 0.0361415, -0.141938, 1.01733, 0.177742, -0.38635, 0.757551, 0.0, -0.0327364, -0.0717398, -0.113955, -0.377849, 1.0, 0.387678, 0.39208, 0.405802, 0.430539, 0.469721, 0.529839, 0.623667, 0.77914, 1.0, 1.0, 0.0707573, 0.0438396, 0.0441252, -0.146296, 0.965503, -0.634059, -0.264367, 1.0, 0.0, -0.0406204, -0.0947437, -0.16551, -0.431644, 1.0, 0.380899, 0.385225, 0.398706, 0.423011, 0.461508, 0.520575, 0.612762, 0.765517, 1.0, 1.0, 0.0972858, 0.0530127, 0.0528144, -0.178089, 0.934246, -0.350699, -0.380032, -1.0, 0.0, -0.0247269, 0.211858, -0.283235, -1.0, 1.0, 0.372639, 0.376871, 0.390061, 0.413838, 0.4515, 0.509287, 0.599474, 0.748917, 1.0, 1.0, 0.12537, 0.0561076, 0.0710391, -0.1877, 0.934602, 0.0169474, -0.497882, -1.0, 1.0, -0.103308, -0.969189, -0.262041, -0.0982217, 1.0, 0.36393, 0.368063, 0.380944, 0.404166, 0.440948, 0.497384, 0.585464,  ...
#  0.727265, 0.0683707, -0.060298, 0.010295, 0.845663, -1.0, 0.134361, 1.0, 0.0, -0.834909, 0.0, -0.634912, -1.98682e-8, 0.0, 0.281389, 0.284585, 0.294544, 0.312499, 0.340939, 0.384575, 0.452678, 0.565525, 0.77655, 1.0, 0.746011, 0.0375412, -0.0551431, -0.0150916, 0.862632, 0.236312, 0.0178389, -1.0, 0.0, -0.78736, 0.605865, -0.621021, 0.0975946, 0.0, 0.280706, 0.283894, 0.293829, 0.311741, 0.340111, 0.383641, 0.451579, 0.564152, 0.774665, 1.0, 0.785374, 0.0786266, -0.0311405, -0.0211573, 0.828037, -0.406729, -0.0977501, -1.0, 0.0, -0.820317, -0.37337, -0.560943, -0.466121, 1.0, 0.279792, 0.282969, 0.292873, 0.310725, 0.339004, 0.382392, 0.450108, 0.562315, 0.772142, 1.0, 0.80317, 0.0357787, -0.0478108, -0.0385309, 0.826257, -0.0270325, -0.13612, -0.321012, 0.0, -0.820255, 0.0, -0.561403, -0.191634, 0.0, 0.277983, 0.28114, 0.290979, 0.308716, 0.336812, 0.379919, 0.447198, 0.55868, 0.76715, 1.0, 0.806669, 0.00710457, -0.0760461, -0.056696, 0.832537, 0.0795471, -0.115097, 0.173014, 0.0, -0.745473, 0.938607, -0.678528, -1.0, 1.0, 0.275311, 0.278438, 0.288182, 0.305749, 0.333575, 0.376268, 0.4429, 0.55331, 0.759777, 1.0, 0.799635, -0.01525, -0.0622213, -0.07691, 0.909396, 0.98636, -0.230417, -1.0, 0.0, -0.673871, 1.0, -0.746773, -0.603125, 1.0, 0.271813, 0.2749, 0.28452, 0.301864, 0.329336, 0.371487, 0.437272, 0.546279, 0.750122, 1.0, 0.834737, 0.059967, -0.0119836, -0.0275425, 0.887379, -0.123906, -0.350317, -0.999682, 0.0, -0.78803, -0.407889, -0.643808, 0.0203681, 1.0, 0.271575, 0.274659, 0.284271, 0.3016, 0.329048, 0.371162, 0.436889, 0.545801, 0.749466, 1.0, 0.851774, 0.0333025, -0.0316454, -0.0498354, 0.886174, 0.0381716, -0.225702, 1.0, 0.0, -0.828134, -0.425627, -0.635533, 1.98682e-8, 0.0, 0.269343, 0.272401, 0.281935, 0.299121, 0.326343, 0.368111, 0.433298, 0.541315, 0.743306, 1.0, 0.858452, 0.0127083, -0.0418502, -0.00247827, 0.840237, -0.549926, -0.102928, 0.999818, 0.0, -0.833719, 5.87106e-6, -0.635551, -0.0529547, 1.0, 0.269296, 0.272354, 0.281886, 0.299069, 0.326286, 0.368047, 0.433223, 0.541221, 0.743177, 1.0, 0.861138, 0.00519644, -0.0234602, 0.0122024, 0.803656, -0.405757, -0.215573, -0.999983, 0.0, -0.834408, -1.00583e-6, -0.635012, 0.00713541, 0.0, 0.269887, 0.272952, 0.282504, 0.299725, 0.327002, 0.368854, 0.434174, 0.542408, 0.744807, 1.0, 0.85718, -0.00791846, -0.00433034, 0.00398532, 0.793309, -0.0718186, -0.32977, -0.999741, 0.0, -0.834105, -8.11368e-6, -0.631608, 0.0348398, 0.0, 0.270067, 0.273134, 0.282693, 0.299926, 0.327221, 0.369101, 0.434464, 0.542771, 0.745306, 1.0, 0.856846, -0.000875578, -0.000247646, 0.0219795, 0.718557, -0.865772, -0.438084, -0.999998, 0.0, -0.834285, -1.72295e-8, -0.626422, 0.043153, 0.0, 0.271111, 0.27419, 0.283786, 0.301085, 0.328486, 0.370528, 0.436144, 0.544869, 0.748187, 1.0, 0.842411, -0.0289687, -0.00592418, 0.0272948, 0.644342, -0.925707, -0.381252, 0.841214, 1.0, -0.817437, 0.21174, -0.625293, 0.00884345, 0.0, 0.272365, 0.275458, 0.285098, 0.302477, 0.330005, 0.372241, 0.43816, 0.547389, 0.751646, 1.0, 0.838043, -0.00859703, 0.0138689, 0.00548939, 0.659593, -0.0124928, -0.490991, -0.445811, 1.0, -0.817333, 8.64267e-7, -0.624817, 0.0029885, 0.0, 0.272589, 0.275685, 0.285333, 0.302726, 0.330276, 0.372548, 0.438521, 0.547839, 0.752265, 1.0, 0.832725, -0.0104085, 0.00345856, 0.00324895, 0.67612, 0.0678971, -0.518253, -0.000253749, 0.0, -0.811595, 0.0681271, -0.625631, -0.00424472, 0.0, 0.272717, 0.275814, 0.285467, 0.302868, 0.330432, 0.372723, 0.438727, 0.548096, 0.752618, 1.0, 0.81757, -0.0303004, 0.0234863, 0.00233136, 0.712313, 0.490613, -0.634954, -1.00008, 1.0, -0.797503, 0.176316, -0.626944, -0.0116961, 0.0, 0.272798, 0.275896, 0.285551, 0.302958, 0.330529, 0.372833, 0.438857, 0.548259, 0.752841, 1.0, 0.810688, -0.0138364, 0.0140333, 0.0131693, 0.66, -0.655496, -0.58798, 0.761559, 1.0, -0.788937, 0.108762, -0.626829, 3.51419e-5, 0.0, 0.273405, 0.27651, 0.286187, 0.303632, 0.331265, 0.373662, 0.439833, 0.549479, 0.754516, 1.0, 0.799805, -0.0212523, 0.00643759, 0.0146668 ...
# , 0.457509, 0.934925, 0.0, 0.0, -0.74551, 1.0, -0.520852, -0.65031, 1.0, 0.247699, 0.250512, 0.259279, 0.275084, 0.300119, 0.33853, 0.398479, 0.497816, 0.683575, 1.0, 0.166215, -0.00476501, 0.0114402, -0.0429617, 1.10054, 2.6077e-8, 0.934907, 0.0, 0.0, -0.799659, -0.356279, -0.469756, 0.499527, 1.0, 0.245926, 0.248719, 0.257424, 0.273116, 0.297971, 0.336108, 0.395628, 0.494253, 0.678683, 1.0, 0.178527, 0.0245094, -0.00317119, -0.0664216, 1.09975, 8.9407e-8, 0.851491, 0.282885, 1.0, -0.834516, -0.393048, -0.585917, -1.0, 1.0, 0.242847, 0.245605, 0.2542, 0.269696, 0.29424, 0.331899, 0.390674, 0.488065, 0.670185, 1.0, 0.182767, 0.0101839, 0.0264483, -0.0301253, 1.0557, -0.510672, 0.96597, 1.00005, 1.0, -0.835143, 4.88013e-6, -0.710296, -1.00239, 1.0, 0.241535, 0.244278, 0.252827, 0.268239, 0.292651, 0.330106, 0.388564, 0.485428, 0.666565, 1.0, 0.171138, -0.0188654, 0.0682044, -0.0188888, 1.13474, 0.989513, 0.850037, -0.999996, 0.0, -0.835228, 0.00174041, -0.635663, -0.0225139, 1.0, 0.240886, 0.243622, 0.252148, 0.267519, 0.291865, 0.32922, 0.38752, 0.484124, 0.664775, 1.0, 0.167985, -0.00558621, 0.0655931, -0.00517334, 1.09183, -0.536287, 0.970606, 0.999947, 0.0, -0.835103, 6.14673e-6, -0.635364, 0.00559235, 1.0, 0.240679, 0.243412, 0.251931, 0.267288, 0.291613, 0.328936, 0.387186, 0.483707, 0.664201, 1.0, 0.15866, -0.018316, 0.0690288, -0.0179022, 1.11435, 0.14221, 0.934907, 0.0, 0.0, -0.834915, 0.000160702, -0.634925, -0.00019899, 1.0, 0.239768, 0.242491, 0.250977, 0.266276, 0.290509, 0.327691, 0.385721, 0.481877, 0.661688, 1.0, 0.151385, -0.0147462, 0.0585613, -0.00471819, 1.11331, 3.72529e-8, 0.918065, 0.601308, 1.0, -0.830744, 0.0555445, -0.634691, 0.0, 1.0, 0.239511, 0.242231, 0.250709, 0.265991, 0.290198, 0.32734, 0.385308, 0.48136, 0.660979, 1.0, 0.151804, 0.00129587, 0.0238371, 0.0228358, 1.10207, 0.00163649, 0.898231, -0.0636276, 1.0, -0.830934, 2.96533e-6, -0.558536, 0.631375, 1.0, 0.240633, 0.243366, 0.251883, 0.267237, 0.291558, 0.328873, 0.387112, 0.483615, 0.664076, 1.0, 0.165946, 0.028317, 0.00703283, 0.0292289, 1.10187, -2.08616e-7, 0.861898, -0.318111, 1.0, -0.830921, 1.49012e-8, -0.59367, -0.293018, 1.0, 0.242055, 0.244804, 0.253371, 0.268816, 0.29328, 0.330816, 0.3894, 0.486473, 0.667999, 1.0, 0.17594, 0.019998, 0.00655151, 0.0248383, 1.07243, -0.369389, 0.913682, 0.432816, 1.0, -0.830903, 3.72529e-8, -0.598904, -0.0442772, 1.0, 0.243255, 0.246017, 0.254627, 0.270149, 0.294734, 0.332457, 0.39133, 0.488884, 0.671311, 1.0, 0.185243, 0.0185692, 0.00404531, 0.0358965, 1.02153, -0.634968, 1.00575, 0.895878, 1.0, -0.830558, 0.00899918, -0.558853, 0.330335, 1.0, 0.244967, 0.247749, 0.25642, 0.27205, 0.296809, 0.334797, 0.394085, 0.492326, 0.676036, 1.0, 0.181256, -0.00658551, -0.0185952, 0.0144472, 1.04571, 0.0203487, 0.934903, 7.46051e-6, 1.0, -0.812929, 0.229715, -0.678513, -0.999994, 1.0, 0.245552, 0.248341, 0.257032, 0.2727, 0.297518, 0.335596, 0.395026, 0.493502, 0.677651, 1.0, 0.172028, -0.0184731, 0.00578572, 0.00929431, 1.05829, 0.157687, 0.934907, 0.0, 1.0, -0.815108, 4.47035e-8, -0.556651, 0.999933, 1.0, 0.245953, 0.248746, 0.257452, 0.273145, 0.298004, 0.336144, 0.395671, 0.494307, 0.678757, 1.0, 0.167764, -0.00856492, 0.00128376, 0.0172848, 1.0244, -0.422675, 1.02827, 0.889558, 1.0, -0.817089, 5.21541e-8, -0.434689, 1.00002, 1.0, 0.246744, 0.249546, 0.258279, 0.274023, 0.298962, 0.337225, 0.396943, 0.495896, 0.680939, 1.0, 0.149774, -0.0359944, -0.00698895, -0.0158569, 1.09276, 0.995626, 0.89492, -1.00129, 1.0, -0.811768, 0.0975086, -0.311575, 0.99983, 0.0, 0.245953, 0.248746, 0.257452, 0.273145, 0.298003, 0.336144, 0.395671, 0.494307, 0.678757, 1.0, 0.142433, -0.0146819, -0.00281, -0.0160313, 1.05975, -0.415189, 1.01455, 1.0, 1.0, -0.813587, 0.0, -0.189164, 1.0, 0.0, 0.24517, 0.247955, 0.256633, 0.272276, 0.297055, 0.335075, 0.394412, 0.492734, 0.676598, 1.0, 0.12436, -0.0363806, 0.0146929, 0.0159179, 1.12219, 0.788899, 0.895922, -0.999937, 0.0, -0.783538, 0.408543, -0.309786, -0.994104, 1.0, 0.24584, 0. ...
# 4515, 0.761431, 1.0, 0.426578, 0.0162457, 0.0498135, -0.0392991, 1.13557, 6.55651e-7, -0.599054, 0.114143, 0.0, -0.753355, -0.190649, -0.504357, -0.304182, 0.0, 0.274156, 0.277269, 0.286973, 0.304466, 0.332175, 0.374689, 0.441042, 0.550989, 0.756589, 1.0, 0.448255, 0.0434084, 0.0603613, -0.057466, 1.124, -0.144049, -0.595267, 0.030067, 0.0, -0.833065, -0.988443, -0.517985, -0.128649, 0.0, 0.271514, 0.274598, 0.284208, 0.301533, 0.328975, 0.371079, 0.436792, 0.54568, 0.749299, 1.0, 0.464016, 0.0315228, 0.0474447, -0.0670408, 1.12034, -0.00732645, -0.712069, -1.0, 0.0, -0.827421, 0.0893177, -0.635036, -1.0, 0.0, 0.268413, 0.271461, 0.280962, 0.298089, 0.325217, 0.366841, 0.431803, 0.539447, 0.740741, 1.0, 0.463638, 0.000344751, -0.000264113, -0.00111026, 1.1211, -0.000622796, -0.635, -0.00126057, 0.0, -0.825281, -3.60601e-5, -0.634912, 0.000585674, 1.0, 0.268613, 0.271663, 0.281171, 0.298311, 0.325459, 0.367114, 0.432124, 0.539848, 0.741292, 1.0, 0.458867, -0.00955976, -0.0189384, 0.0244318, 1.12109, -0.00027423, -0.626375, 0.0721792, 0.0, -0.821673, 0.072076, -0.512992, 0.999997, 1.0, 0.269743, 0.272806, 0.282354, 0.299566, 0.326828, 0.368658, 0.433943, 0.54212, 0.744411, 1.0, 0.459916, 0.00208469, -0.0351149, 0.0253064, 1.11436, -0.0842369, -0.615569, 0.0902463, 0.0, -0.824193, 0.0, -0.390442, 1.0, 1.0, 0.270929, 0.274006, 0.283596, 0.300883, 0.328266, 0.370279, 0.435851, 0.544504, 0.747685, 1.0, 0.458462, -0.00290767, -0.0366137, 0.009009, 1.11439, 5.58794e-9, -0.615628, 0.0, 0.0, -0.822143, 0.0649454, -0.266575, 1.0, 0.0, 0.271341, 0.274423, 0.284027, 0.30134, 0.328764, 0.370842, 0.436513, 0.545331, 0.748821, 1.0, 0.465791, 0.0146878, -0.0691331, 0.0292767, 1.09978, -0.183563, -0.599364, 0.135833, 0.0, -0.804335, 0.272217, -0.278764, -0.242678, 1.0, 0.272721, 0.275818, 0.285471, 0.302872, 0.330436, 0.372728, 0.438733, 0.548104, 0.752628, 1.0, 0.469076, 0.00659377, -0.0447422, 0.00628483, 1.13157, 0.412136, -0.717402, -1.0, 0.0, -0.812338, 0.0, -0.265246, -0.0204608, 1.0, 0.273, 0.2761, 0.285763, 0.303183, 0.330775, 0.373109, 0.439182, 0.548665, 0.753399, 1.0, 0.464005, -0.00924427, -0.0606496, 0.0113807, 1.11731, 2.23517e-8, -0.634907, 0.0, 0.0, -0.795298, 0.187951, -0.279716, -0.0971271, 0.0, 0.273752, 0.276861, 0.286551, 0.304018, 0.331686, 0.374138, 0.440393, 0.550178, 0.755476, 1.0, 0.446148, -0.0356565, -0.0912251, 0.00323433, 1.11446, -2.98023e-8, -0.511914, 1.0, 0.0, -0.715451, 1.0, -0.363059, -0.70603, 0.0, 0.273839, 0.276949, 0.286642, 0.304115, 0.331791, 0.374256, 0.440532, 0.550352, 0.755715, 1.0, 0.447744, 0.00304167, -0.0442963, 0.000270529, 1.11512, -0.00229461, -0.531224, -0.154337, 1.0, -0.711267, 0.0615674, -0.358075, -0.0590382, 1.0, 0.273884, 0.276994, 0.286689, 0.304165, 0.331846, 0.374318, 0.440604, 0.550442, 0.755839, 1.0, 0.437857, -0.0199635, -0.08606, 0.0151706, 1.11043, 0.0116369, -0.40534, 0.568445, 0.0, -0.678684, 0.435554, -0.489933, -0.997133, 1.0, 0.274589, 0.277707, 0.287427, 0.304948, 0.3327, 0.375281, 0.441739, 0.551859, 0.757785, 1.0, 0.452105, 0.0285789, -0.0503975, 0.0178445, 1.09965, -0.248252, -0.396993, 0.0871552, 0.0, -0.75909, -1.0, -0.364925, 0.926573, 0.0, 0.275441, 0.278569, 0.288318, 0.305893, 0.333732, 0.376445, 0.443108, 0.553571, 0.760135, 1.0, 0.469756, 0.0351978, -0.0505045, -0.0285425, 1.12086, 0.293068, -0.513443, -1.0, 0.0, -0.832447, -0.837718, -0.485533, -1.0, 0.0, 0.274151, 0.277264, 0.286968, 0.304461, 0.332169, 0.374682, 0.441033, 0.550978, 0.756575, 1.0, 0.471446, 0.00341339, -0.0567298, -0.00579438, 1.11846, 1.52737e-7, -0.630801, -1.0, 0.0, -0.834694, -3.72529e-9, -0.372396, 0.922182, 0.0, 0.273885, 0.276996, 0.28669, 0.304166, 0.331847, 0.37432, 0.440607, 0.550445, 0.755843, 1.0, 0.482355, 0.0217448, -0.0865122, -0.0132834, 1.04012, -0.969339, -0.524103, 0.555623, 1.0, -0.834764, 0.0, -0.395671, -0.194861, 0.0, 0.273292, 0.276396, 0.286069, 0.303507, 0.331129, 0.373509, 0.439653, 0.549253, 0.754206, 1.0, 0.497844, 0.031272, -0.0770489, -0.043317, 1.07256, -0.0278 ...
# 0, -0.528127, -0.709415, -0.660571, -1.0, 0.0, 0.325362, 0.329057, 0.340573, 0.361334, 0.394218, 0.444673, 0.523418, 0.653901, 0.897903, 1.0, 0.833338, 0.0982421, 0.162291, -0.137632, 0.701753, -0.184136, 0.0500353, -1.0, 0.0, -0.615738, -1.03026, -0.634908, -1.98682e-8, 0.0, 0.319094, 0.322717, 0.334012, 0.354372, 0.386623, 0.436106, 0.513334, 0.641303, 0.880604, 1.0, 0.862217, 0.0576821, 0.125184, -0.135385, 0.65282, -0.58477, 0.173712, 1.0, 0.0, -0.632807, -0.174449, -0.639255, -1.07136, 1.0, 0.312797, 0.31635, 0.327421, 0.34738, 0.378994, 0.427501, 0.503205, 0.628649, 0.863228, 1.0, 0.890002, 0.0559958, 0.153735, -0.0994322, 0.579944, -0.907727, 0.296282, 0.999887, 0.0, -0.684003, -0.603761, -0.588802, -0.0278134, 1.0, 0.308074, 0.311573, 0.322477, 0.342135, 0.373271, 0.421045, 0.495607, 0.619156, 0.850193, 1.0, 0.924819, 0.0696619, 0.168542, -0.112079, 0.49845, -1.0, 0.416007, 0.972938, 0.0, -0.763893, -1.0, -0.575176, 0.117188, 1.0, 0.302861, 0.306301, 0.317021, 0.336346, 0.366956, 0.413921, 0.487221, 0.60868, 0.835808, 1.0, 0.923701, -0.00232612, 0.137685, -0.141565, 0.500683, 0.0527122, 0.540301, 1.0, 0.0, -0.744718, 0.244685, -0.627692, -0.447748, 1.0, 0.29622, 0.299584, 0.310069, 0.32897, 0.358909, 0.404845, 0.476537, 0.595333, 0.81748, 1.0, 0.931195, 0.0148332, 0.214326, -0.110381, 0.578259, 0.990523, 0.426654, -1.0005, 0.0, -0.778201, -0.410174, -0.630696, -0.0386174, 0.0, 0.291052, 0.294358, 0.304659, 0.323231, 0.352647, 0.397781, 0.468223, 0.584946, 0.803218, 1.0, 0.939924, 0.0173845, 0.237816, -0.101708, 0.644652, 0.846727, 0.350721, -0.669753, 0.0, -0.816873, -0.481818, -0.627908, 0.0226276, 0.0, 0.286294, 0.289545, 0.299679, 0.317946, 0.346882, 0.391278, 0.460568, 0.575383, 0.790086, 1.0, 0.916487, -0.0470777, 0.221203, -0.0825459, 0.747155, 1.30359, 0.238035, -1.0, 0.0, -0.817949, 4.26173e-6, -0.630025, -0.0361031, 0.0, 0.282393, 0.2856, 0.295596, 0.313614, 0.342156, 0.385947, 0.454293, 0.567543, 0.779321, 1.0, 0.890009, -0.0530049, 0.228605, -0.0650244, 0.825497, 1.00002, 0.122136, -0.999973, 0.0, -0.817663, -1.66893e-6, -0.627261, 0.0263997, 0.0, 0.279305, 0.282477, 0.292363, 0.310185, 0.338414, 0.381726, 0.449325, 0.561337, 0.770798, 1.0, 0.865226, -0.0496333, 0.210063, -0.0459666, 0.798653, -0.318996, 0.245741, 0.999999, 0.0, -0.817686, 0.0, -0.620038, 0.0565015, 0.0, 0.27711, 0.280257, 0.290066, 0.307748, 0.335755, 0.378727, 0.445795, 0.556926, 0.764743, 1.0, 0.840699, -0.0491865, 0.22109, -0.0578741, 0.815971, 0.247572, 0.131809, -1.0, 0.0, -0.812663, 0.065471, -0.619213, 4.27167e-7, 0.0, 0.274361, 0.277477, 0.287188, 0.304694, 0.332424, 0.374969, 0.441372, 0.551401, 0.757155, 1.0, 0.822781, -0.0360482, 0.203855, -0.0566439, 0.734389, -1.00185, 0.259499, 0.999885, 0.0, -0.812838, 3.97414e-5, -0.618072, 0.00712671, 0.0, 0.271673, 0.274759, 0.284375, 0.30171, 0.329167, 0.371296, 0.437048, 0.545999, 0.749738, 1.0, 0.800224, -0.045154, 0.216271, -0.0780095, 0.708467, -0.299774, 0.22656, -0.310008, 0.0, -0.812958, -1.19209e-7, -0.617885, -0.000886599, 0.0, 0.267973, 0.271017, 0.280501, 0.2976, 0.324684, 0.366239, 0.431096, 0.538563, 0.739527, 1.0, 0.778071, -0.0477276, 0.196192, -0.00022312, 0.635206, -0.838252, 0.358793, 1.00086, 0.0, -0.815211, 1.90735e-6, -0.58313, 0.198864, 1.0, 0.268474, 0.271523, 0.281026, 0.298156, 0.325291, 0.366924, 0.431901, 0.539569, 0.740909, 1.0, 0.751076, -0.0542579, 0.185696, 0.0282243, 0.595151, -0.485268, 0.450305, 0.732201, 0.0, -0.802571, 0.211301, -0.713577, -1.00005, 1.0, 0.269766, 0.272829, 0.282378, 0.299591, 0.326856, 0.368689, 0.433979, 0.542165, 0.744473, 1.0, 0.729179, -0.0468102, 0.195921, 0.0295115, 0.531395, -0.735248, 0.591214, 1.02447, 1.0, -0.818274, -1.54972e-6, -0.690552, -0.0247534, 0.0, 0.271405, 0.274487, 0.284093, 0.301411, 0.328842, 0.370929, 0.436616, 0.545459, 0.748996, 1.0, 0.703096, -0.0534706, 0.1946, 0.0123138, 0.629057, 0.96446, 0.454565, -0.999914, 1.0, -0.816908, 0.0571032, -0.635732, 0.00577952, 0.0, 0.272245, 0.275337, 0.284973, 0.302345, 0. ...
# 299701, 0.338059, 0.397924, 0.497122, 0.682623, 1.0, 0.172797, -0.0134487, 0.0111358, 0.00287095, 1.0724, -0.54719, 0.895871, 0.999984, 1.0, -0.811016, 1.19954e-6, -0.234446, 1.00035, 1.0, 0.247459, 0.250269, 0.259028, 0.274817, 0.299828, 0.338202, 0.398093, 0.497333, 0.682912, 1.0, 0.177883, 0.0100696, 0.0176931, 0.00119954, 1.07686, 0.070065, 0.904641, 0.183436, 1.0, -0.810257, 0.0389209, -0.352726, -0.998058, 1.0, 0.247526, 0.250337, 0.259098, 0.274893, 0.29991, 0.338294, 0.398202, 0.497469, 0.683099, 1.0, 0.175713, -0.00440075, 0.0229892, 0.00592113, 1.12135, 0.7356, 0.764097, -1.00011, 1.0, -0.803203, 0.113833, -0.448146, -0.82329, 1.0, 0.247821, 0.250636, 0.259407, 0.27522, 0.300267, 0.338698, 0.398677, 0.498062, 0.683913, 1.0, 0.184803, 0.0182015, 0.0189168, 0.0125487, 1.12131, 0.0, 0.741507, -0.200408, 1.0, -0.799856, 0.0619392, -0.566177, -1.0, 1.0, 0.248441, 0.251262, 0.260056, 0.275908, 0.301018, 0.339544, 0.399673, 0.499307, 0.685623, 1.0, 0.195385, 0.0212717, 0.0507601, -0.00779703, 1.09932, -0.267796, 0.86225, 1.0, 1.0, -0.88036, -1.0, -0.443977, 1.0, 1.0, 0.2481, 0.250917, 0.259699, 0.275529, 0.300604, 0.339078, 0.399124, 0.498621, 0.684681, 1.0, 0.168923, -0.0532305, 0.00710603, -0.0293737, 1.15835, 0.742019, 0.982047, 1.0, 0.0, -0.812654, 0.864543, -0.559369, -1.0, 0.0, 0.246605, 0.249406, 0.258134, 0.27387, 0.298794, 0.337035, 0.39672, 0.495618, 0.680557, 1.0, 0.174694, -0.0103666, 0.0056757, -0.0175794, 1.13536, 4.47035e-8, 0.934944, 0.0, 0.0, -0.769472, -0.373432, -0.614025, 0.232744, 1.0, 0.246131, 0.248926, 0.257638, 0.273343, 0.298219, 0.336388, 0.395958, 0.494665, 0.679249, 1.0, 0.181127, 0.0100049, 0.0299822, -0.0168385, 1.13037, -0.000168841, 0.820381, -1.00002, 0.0, -0.802329, -0.218007, -0.568794, 0.603262, 1.0, 0.245718, 0.248509, 0.257206, 0.272885, 0.297719, 0.335823, 0.395293, 0.493836, 0.67811, 1.0, 0.169575, -0.0231372, 0.0235301, -0.00124886, 1.12798, -0.00590019, 0.815735, 0.746418, 1.0, -0.804268, 1.93715e-7, -0.433679, 0.999823, 1.0, 0.245619, 0.248408, 0.257102, 0.272775, 0.297599, 0.335688, 0.395134, 0.493636, 0.677836, 1.0, 0.165764, -0.00738253, -0.000146199, 0.00134038, 1.1172, 0.00170613, 0.807283, 0.0619395, 1.0, -0.805274, 0.0123333, -0.408199, 0.306645, 1.0, 0.24574, 0.24853, 0.257228, 0.272908, 0.297745, 0.335853, 0.395328, 0.493879, 0.678169, 1.0, 0.161874, -0.0078003, 0.00534852, 0.00616377, 1.08753, -0.368104, 0.927532, 0.999994, 1.0, -0.792723, 0.175045, -0.512622, -0.874789, 1.0, 0.246017, 0.248811, 0.257518, 0.273216, 0.298081, 0.336231, 0.395773, 0.494435, 0.678933, 1.0, 0.172919, 0.0219343, 0.0193437, -0.0320997, 1.12051, 0.420752, 0.809407, -1.0, 0.0, -0.866449, -0.870149, -0.594645, -0.738336, 1.0, 0.244527, 0.247304, 0.255959, 0.271562, 0.296276, 0.334195, 0.393377, 0.491441, 0.674822, 1.0, 0.157326, -0.0188732, 0.00357822, -0.0377964, 1.12624, -2.98023e-8, 0.930671, 1.0, 0.0, -0.834918, 0.0, -0.734917, -1.0, 0.0, 0.24293, 0.245689, 0.254288, 0.269789, 0.294341, 0.332013, 0.390808, 0.488232, 0.670416, 1.0, 0.160492, 0.00721209, 0.0281719, -0.0226429, 1.12586, 3.72529e-8, 0.837107, 0.377673, 1.0, -0.834908, -3.72529e-9, -0.614998, 0.999999, 0.0, 0.24189, 0.244637, 0.253198, 0.268633, 0.29308, 0.330591, 0.389134, 0.486141, 0.667543, 1.0, 0.176424, 0.0320157, -0.00396409, -0.0181133, 1.12364, 0.000558615, 0.802075, -0.254314, 1.0, -0.832545, -0.603663, -0.533584, 1.07518, 1.0, 0.24109, 0.243828, 0.252362, 0.267745, 0.292112, 0.329499, 0.387848, 0.484535, 0.665338, 1.0, 0.168211, -0.0194475, 0.00411568, -0.00418795, 1.11903, -0.00021217, 0.926011, 0.999983, 1.0, -0.83388, 2.03997e-5, -0.455976, 0.999011, 1.0, 0.241219, 0.243958, 0.252496, 0.267888, 0.292268, 0.329674, 0.388055, 0.484793, 0.665693, 1.0, 0.157756, -0.0182961, 0.00135032, 0.00441391, 1.11954, 0.000422202, 0.927208, 0.0, 0.0, -0.835538, -2.0273e-5, -0.319778, 1.00011, 1.0, 0.24155, 0.244293, 0.252843, 0.268256, 0.292669, 0.330127, 0.388588, 0.485459, 0.666607, 1.0, 0.144758, -0.0260448, -0.000631906, -0.003364 ...
# Excessive output truncated after 524328 bytes.
# type Param has no field rewards
#
# Stacktrace:
#  [1] #differentiate#1(::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, ::Function, ::Function, ::Param{History}) at /Users/jenniferdawkins/.julia/packages/AutoGrad/eAmjh/src/core.jl:57
#  [2] differentiate(::Function, ::Param{History}) at /Users/jenniferdawkins/.julia/packages/AutoGrad/eAmjh/src/core.jl:45
#  [3] (::getfield(AutoGrad, Symbol("##gradfun#6#7")){typeof(update_policy),Int64,Bool})(::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, ::Function, ::History) at /Users/jenniferdawkins/.julia/packages/AutoGrad/eAmjh/src/core.jl:139
#  [4] (::getfield(AutoGrad, Symbol("#gradfun#8")){getfield(AutoGrad, Symbol("##gradfun#6#7")){typeof(update_policy),Int64,Bool}})(::History) at /Users/jenniferdawkins/.julia/packages/AutoGrad/eAmjh/src/core.jl:135
#  [5] top-level scope at ./In[39]:53

# %%
dist = Normal(0,4)
log(pdf(dist, .3);
action = rand(dist,a_n)
log.(pdf(dist,action))
# Out:
# ┌ Warning: `pdf(d::UnivariateDistribution, X::AbstractArray)` is deprecated, use `pdf.(d, X)` instead.
# │   caller = top-level scope at In[25]:4
# └ @ Core In[25]:4
# 4-element Array{Float64,1}:
#  -2.4038529024248714
#  -2.33690898767053
#  -3.513541775242507
#  -3.3506354417065

# %%
rand(3,3).*(2).-1
# Out:
# 3×3 Array{Float64,2}:
#  -0.050383    0.360395   0.984606
#   0.0547567  -0.224643   0.585206
#   0.791885    0.373463  -0.857316

# %%
episode_count = 2000;
min_epsilon = 0.01;
decay_rate = 5/episode_count;
# Out:
# 0.0912641486376598

# %%
# General Algorithm for Q learning

# For each step in each episode: 
#     Use policy defined by training network to pick actions
#     Update experience replay
# After each episode: 
# Sample from experience replay
# Update training net; (update target net after x episodes)

# using Gym
reward = 0;
episode_count = 2000;
min_epsilon = 0.01;
decay_rate = 5/episode_count;

for i=1:episode_count
    # set epsilon for exploring policy
    epsilon = min_epsilon + (1.0 - min_epsilon)*exp(-decay_rate*i)
    total = 0
    ob = reset!(env)
#     render(env)#comment out this line if you do not want to visualize the environment
    while true
        Q_values = m(ob)
        # exploration
        if epsilon > Random.rand()
            action = Random.rand(env.action_space.shape[1])
        else
            # take max of Q_values
#         action = sample(env.action_space)
        end
        ob, reward, done, information = step!(env, action)
        total += reward
#         render(env)#comment out this line if you do not want to visualize the environment
        done && break
    end
    # Experience reply
    # update training net 
    i%10 && 
    println("episode $i total Rewards: $total")
end
# Out:
# episode 1 total Rewards: -85.97788289192233
# episode 2 total Rewards: -98.68037809058097
# episode 3 total Rewards: -92.41382523298962
# episode 4 total Rewards: -99.93802021494935
# episode 5 total Rewards: -79.69650269939272
# episode 6 total Rewards: -102.57114505678385
# episode 7 total Rewards: -110.65297324995726
# episode 8 total Rewards: -100.0879210012217
# episode 9 total Rewards: -98.46423048953291
# episode 10 total Rewards: -85.04734643681674

# %%
sample(env.action_space)
# Out:
# 4-element Array{Float64,1}:
#   0.5131067509384377
#   0.8626462959402228
#  -0.3850172680270889
#   0.40907506858505505

# %%
env.action_space.shape[1]
# Out:
# 4

# %%
Random.rand(env.action_space.shape[1])
# Out:
# 4-element Array{Float64,1}:
#  0.5091860357094704
#  0.46913460209260993
#  0.03589676414598042
#  0.27638164170088775

# %%
# State consists of hull angle speed, angular velocity, horizontal speed, vertical speed,
# position of joints and joints angular speed, legs contact with ground, and 10 lidar
# rangefinder measurements to help to deal with the hardcore version. There's no coordinates
# in the state vector. Lidar is less useful in normal version, but it works.

# %%
env.observation_space
# Out:
# BoxS(Float32[-Inf, -Inf, -Inf, -Inf, -Inf, -Inf, -Inf, -Inf, -Inf, -Inf  …  -Inf, -Inf, -Inf, -Inf, -Inf, -Inf, -Inf, -Inf, -Inf, -Inf], Float32[Inf, Inf, Inf, Inf, Inf, Inf, Inf, Inf, Inf, Inf  …  Inf, Inf, Inf, Inf, Inf, Inf, Inf, Inf, Inf, Inf], (24,))

# %%
env.action_space
# I think this is force on 4 joints
# limits: -1 to 1
# Out:
# BoxS(Float32[-1.0, -1.0, -1.0, -1.0], Float32[1.0, 1.0, 1.0, 1.0], (4,))

# %%
env.action_space.sample()
# Out:
# type BoxS has no field sample
#
# Stacktrace:
#  [1] getproperty(::Any, ::Symbol) at ./sysimg.jl:18
#  [2] top-level scope at In[44]:1
